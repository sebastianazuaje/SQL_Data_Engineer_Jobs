# %% [markdown]
# #Data Analyst

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# JSON data de la Query 1
data_Q1 = [
  {
    "titulo_puesto": "Data Analyst",
    "salario_anual": 650000.0,
    "compañía": "Mantys",
    "tipo_esquema": "Full-time"
  },
  {
    "titulo_puesto": "Director of Analytics",
    "salario_anual": 336500.0,
    "compañía": "Meta",
    "tipo_esquema": "Full-time"
  },
  {
    "titulo_puesto": "Associate Director- Data Insights",
    "salario_anual": 255829.5,
    "compañía": "AT&T",
    "tipo_esquema": "Full-time"
  },
  {
    "titulo_puesto": "Data Analyst, Marketing",
    "salario_anual": 232423.0,
    "compañía": "Pinterest Job Advertisements",
    "tipo_esquema": "Full-time"
  },
  {
    "titulo_puesto": "Data Analyst (Hybrid/Remote)",
    "salario_anual": 217000.0,
    "compañía": "Uclahealthcareers",
    "tipo_esquema": "Full-time"
  },
  {
    "titulo_puesto": "Principal Data Analyst (Remote)",
    "salario_anual": 205000.0,
    "compañía": "SmartAsset",
    "tipo_esquema": "Full-time"
  },
  {
    "titulo_puesto": "Director, Data Analyst - HYBRID",
    "salario_anual": 189309.0,
    "compañía": "Inclusively",
    "tipo_esquema": "Full-time"
  },
  {
    "titulo_puesto": "Principal Data Analyst, AV Performance Analysis",
    "salario_anual": 189000.0,
    "compañía": "Motional",
    "tipo_esquema": "Full-time"
  },
  {
    "titulo_puesto": "Principal Data Analyst",
    "salario_anual": 186000.0,
    "compañía": "SmartAsset",
    "tipo_esquema": "Full-time"
  },
  {
    "titulo_puesto": "ERM Data Analyst",
    "salario_anual": 184000.0,
    "compañía": "Get It Recruit - Information Technology",
    "tipo_esquema": "Full-time"
  }
]

df = pd.DataFrame(data_Q1)

salary_by_company = df.groupby('compañía')['salario_anual'].mean().sort_values(ascending=False)
job_by_company = df.groupby('compañía')['titulo_puesto'].agg(lambda x: x.value_counts().index[0])

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 8), sharey=True)

sns.barplot(x=salary_by_company.values, y=salary_by_company.index, palette="viridis", ax=ax1)
ax1.set_title("Top 10 puestos de trabajo 2023")
ax1.set_xlabel("Salario medio (USD)")
ax1.set_ylabel("Compañía")

for i, company in enumerate(salary_by_company.index):
    ax2.text(0, i, job_by_company[company], va='center')
ax2.set_title("Puesto de trabajo más común")
ax2.set_xlim(0, 1)
ax2.axis('off')
plt.tight_layout()
plt.show()
# plt.savefig('Top_10_trabajos_company.png', dpi=300, bbox_inches='tight')
# plt.close()
# Out:
# <ipython-input-1-26293876fe0b>:76: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=salary_by_company.values, y=salary_by_company.index, palette="viridis", ax=ax1)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# JSON data de la Query 3
data_q3 = [
    {"job_id": 552322, "job_title_short": "Data Analyst", "salary_year_avg": 255829.5, "job_title": "Associate Director- Data Insights", "company_name": "AT&T", "habilidades": "sql"},
    {"job_id": 552322, "job_title_short": "Data Analyst", "salary_year_avg": 255829.5, "job_title": "Associate Director- Data Insights", "company_name": "AT&T", "habilidades": "python"},
    {"job_id": 552322, "job_title_short": "Data Analyst", "salary_year_avg": 255829.5, "job_title": "Associate Director- Data Insights", "company_name": "AT&T", "habilidades": "r"},
    {"job_id": 552322, "job_title_short": "Data Analyst", "salary_year_avg": 255829.5, "job_title": "Associate Director- Data Insights", "company_name": "AT&T", "habilidades": "azure"},
    {"job_id": 552322, "job_title_short": "Data Analyst", "salary_year_avg": 255829.5, "job_title": "Associate Director- Data Insights", "company_name": "AT&T", "habilidades": "databricks"},
    {"job_id": 552322, "job_title_short": "Data Analyst", "salary_year_avg": 255829.5, "job_title": "Associate Director- Data Insights", "company_name": "AT&T", "habilidades": "aws"},
    {"job_id": 552322, "job_title_short": "Data Analyst", "salary_year_avg": 255829.5, "job_title": "Associate Director- Data Insights", "company_name": "AT&T", "habilidades": "pandas"},
    {"job_id": 552322, "job_title_short": "Data Analyst", "salary_year_avg": 255829.5, "job_title": "Associate Director- Data Insights", "company_name": "AT&T", "habilidades": "pyspark"},
    {"job_id": 552322, "job_title_short": "Data Analyst", "salary_year_avg": 255829.5, "job_title": "Associate Director- Data Insights", "company_name": "AT&T", "habilidades": "jupyter"},
    {"job_id": 552322, "job_title_short": "Data Analyst", "salary_year_avg": 255829.5, "job_title": "Associate Director- Data Insights", "company_name": "AT&T", "habilidades": "excel"},
    {"job_id": 552322, "job_title_short": "Data Analyst", "salary_year_avg": 255829.5, "job_title": "Associate Director- Data Insights", "company_name": "AT&T", "habilidades": "tableau"},
    {"job_id": 552322, "job_title_short": "Data Analyst", "salary_year_avg": 255829.5, "job_title": "Associate Director- Data Insights", "company_name": "AT&T", "habilidades": "power bi"},
    {"job_id": 552322, "job_title_short": "Data Analyst", "salary_year_avg": 255829.5, "job_title": "Associate Director- Data Insights", "company_name": "AT&T", "habilidades": "powerpoint"},
    {"job_id": 99305, "job_title_short": "Data Analyst", "salary_year_avg": 232423.0, "job_title": "Data Analyst, Marketing", "company_name": "Pinterest Job Advertisements", "habilidades": "sql"},
    {"job_id": 99305, "job_title_short": "Data Analyst", "salary_year_avg": 232423.0, "job_title": "Data Analyst, Marketing", "company_name": "Pinterest Job Advertisements", "habilidades": "python"},
    {"job_id": 99305, "job_title_short": "Data Analyst", "salary_year_avg": 232423.0, "job_title": "Data Analyst, Marketing", "company_name": "Pinterest Job Advertisements", "habilidades": "r"},
    {"job_id": 99305, "job_title_short": "Data Analyst", "salary_year_avg": 232423.0, "job_title": "Data Analyst, Marketing", "company_name": "Pinterest Job Advertisements", "habilidades": "hadoop"},
    {"job_id": 99305, "job_title_short": "Data Analyst", "salary_year_avg": 232423.0, "job_title": "Data Analyst, Marketing", "company_name": "Pinterest Job Advertisements", "habilidades": "tableau"},
    {"job_id": 1021647, "job_title_short": "Data Analyst", "salary_year_avg": 217000.0, "job_title": "Data Analyst (Hybrid/Remote)", "company_name": "Uclahealthcareers", "habilidades": "sql"},
    {"job_id": 1021647, "job_title_short": "Data Analyst", "salary_year_avg": 217000.0, "job_title": "Data Analyst (Hybrid/Remote)", "company_name": "Uclahealthcareers", "habilidades": "crystal"},
    {"job_id": 1021647, "job_title_short": "Data Analyst", "salary_year_avg": 217000.0, "job_title": "Data Analyst (Hybrid/Remote)", "company_name": "Uclahealthcareers", "habilidades": "oracle"},
    {"job_id": 1021647, "job_title_short": "Data Analyst", "salary_year_avg": 217000.0, "job_title": "Data Analyst (Hybrid/Remote)", "company_name": "Uclahealthcareers", "habilidades": "tableau"},
    {"job_id": 1021647, "job_title_short": "Data Analyst", "salary_year_avg": 217000.0, "job_title": "Data Analyst (Hybrid/Remote)", "company_name": "Uclahealthcareers", "habilidades": "flow"},
    {"job_id": 168310, "job_title_short": "Data Analyst", "salary_year_avg": 205000.0, "job_title": "Principal Data Analyst (Remote)", "company_name": "SmartAsset", "habilidades": "sql"},
    {"job_id": 168310, "job_title_short": "Data Analyst", "salary_year_avg": 205000.0, "job_title": "Principal Data Analyst (Remote)", "company_name": "SmartAsset", "habilidades": "python"},
    {"job_id": 168310, "job_title_short": "Data Analyst", "salary_year_avg": 205000.0, "job_title": "Principal Data Analyst (Remote)", "company_name": "SmartAsset", "habilidades": "go"},
    {"job_id": 168310, "job_title_short": "Data Analyst", "salary_year_avg": 205000.0, "job_title": "Principal Data Analyst (Remote)", "company_name": "SmartAsset", "habilidades": "snowflake"},
    {"job_id": 168310, "job_title_short": "Data Analyst", "salary_year_avg": 205000.0, "job_title": "Principal Data Analyst (Remote)", "company_name": "SmartAsset", "habilidades": "pandas"},
    {"job_id": 168310, "job_title_short": "Data Analyst", "salary_year_avg": 205000.0, "job_title": "Principal Data Analyst (Remote)", "company_name": "SmartAsset", "habilidades": "numpy"},
    {"job_id": 168310, "job_title_short": "Data Analyst", "salary_year_avg": 205000.0, "job_title": "Principal Data Analyst (Remote)", "company_name": "SmartAsset", "habilidades": "excel"},
    {"job_id": 168310, "job_title_short": "Data Analyst", "salary_year_avg": 205000.0, "job_title": "Principal Data Analyst (Remote)", "company_name": "SmartAsset", "habilidades": "tableau"},
    {"job_id": 168310, "job_title_short": "Data Analyst", "salary_year_avg": 205000.0, "job_title": "Principal Data Analyst (Remote)", "company_name": "SmartAsset", "habilidades": "gitlab"},
]

df = pd.DataFrame(data_q3)

# 1.Salario medio por Compañía

salary_by_company = df.groupby('company_name')['salary_year_avg'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=salary_by_company.values, y=salary_by_company.index, palette="viridis")
plt.title("Salario medio por Compañía")
plt.xlabel("Salario medio (USD)")
plt.ylabel("Compañía")
plt.tight_layout()
# plt.savefig('salario_por_compania.png', dpi=300, bbox_inches='tight')
# plt.close()
plt.show()
# 2.Frecuencia de las skills en cada posición
skills_frequency = df['habilidades'].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=skills_frequency.values, y=skills_frequency.index, palette="magma")
plt.title("Frecuencia de las skills en cada posición")
plt.xlabel("Frecuencia")
plt.ylabel("Skill")
plt.tight_layout()
# plt.savefig('frecuencia_skills.png', dpi=300, bbox_inches='tight')
# plt.close()
# Out:
# <ipython-input-11-5b343216a83b>:48: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=salary_by_company.values, y=salary_by_company.index, palette="viridis")
# <ipython-input-11-5b343216a83b>:60: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=skills_frequency.values, y=skills_frequency.index, palette="magma")

# %% [markdown]
# #Data Scientist

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# JSON data de la Query 1
data_Q1 = [
  {
    "id_trabajo": 40145,
    "alias_trabajo": "Data Scientist",
    "ubicacion": "Anywhere",
    "salario_anual": 550000.0,
    "tipo_esquema": "Full-time",
    "fecha_publicacion": "2023-08-16 16:05:16",
    "titulo_puesto": "Staff Data Scientist/Quant Researcher",
    "compañía": "Selby Jennings"
  },
  {
    "id_trabajo": 1714768,
    "alias_trabajo": "Data Scientist",
    "ubicacion": "Anywhere",
    "salario_anual": 525000.0,
    "tipo_esquema": "Full-time",
    "fecha_publicacion": "2023-09-01 19:24:02",
    "titulo_puesto": "Staff Data Scientist - Business Analytics",
    "compañía": "Selby Jennings"
  },
  {
    "id_trabajo": 1131472,
    "alias_trabajo": "Data Scientist",
    "ubicacion": "Anywhere",
    "salario_anual": 375000.0,
    "tipo_esquema": "Full-time",
    "fecha_publicacion": "2023-07-31 14:05:21",
    "titulo_puesto": "Data Scientist",
    "compañía": "Algo Capital Group"
  },
  {
    "id_trabajo": 1742633,
    "alias_trabajo": "Data Scientist",
    "ubicacion": "Anywhere",
    "salario_anual": 351500.0,
    "tipo_esquema": "Full-time",
    "fecha_publicacion": "2023-07-12 03:07:31",
    "titulo_puesto": "Head of Data Science",
    "compañía": "Demandbase"
  },
  {
    "id_trabajo": 551497,
    "alias_trabajo": "Data Scientist",
    "ubicacion": "Anywhere",
    "salario_anual": 324000.0,
    "tipo_esquema": "Full-time",
    "fecha_publicacion": "2023-05-26 22:04:44",
    "titulo_puesto": "Head of Data Science",
    "compañía": "Demandbase"
  },
  {
    "id_trabajo": 126218,
    "alias_trabajo": "Data Scientist",
    "ubicacion": "Anywhere",
    "salario_anual": 320000.0,
    "tipo_esquema": "Full-time",
    "fecha_publicacion": "2023-03-26 23:46:39",
    "titulo_puesto": "Director Level - Product Management - Data Science",
    "compañía": "Teramind"
  },
  {
    "id_trabajo": 1161630,
    "alias_trabajo": "Data Scientist",
    "ubicacion": "Anywhere",
    "salario_anual": 313000.0,
    "tipo_esquema": "Full-time",
    "fecha_publicacion": "2023-08-23 22:03:48",
    "titulo_puesto": "Director of Data Science & Analytics",
    "compañía": "Reddit"
  },
  {
    "id_trabajo": 38905,
    "alias_trabajo": "Data Scientist",
    "ubicacion": "Anywhere",
    "salario_anual": 300000.0,
    "tipo_esquema": "Full-time",
    "fecha_publicacion": "2023-11-24 14:08:44",
    "titulo_puesto": "Principal Data Scientist",
    "compañía": "Storm5"
  },
  {
    "id_trabajo": 226011,
    "alias_trabajo": "Data Scientist",
    "ubicacion": "Anywhere",
    "salario_anual": 300000.0,
    "tipo_esquema": "Full-time",
    "fecha_publicacion": "2023-08-06 11:00:43",
    "titulo_puesto": "Distinguished Data Scientist",
    "compañía": "Walmart"
  },
  {
    "id_trabajo": 129924,
    "alias_trabajo": "Data Scientist",
    "ubicacion": "Anywhere",
    "salario_anual": 300000.0,
    "tipo_esquema": "Full-time",
    "fecha_publicacion": "2023-01-21 11:09:36",
    "titulo_puesto": "Director of Data Science",
    "compañía": "Storm4"
  }
]


df = pd.DataFrame(data_Q1)

salary_by_company = df.groupby('compañía')['salario_anual'].mean().sort_values(ascending=False)
job_by_company = df.groupby('compañía')['titulo_puesto'].agg(lambda x: x.value_counts().index[0])

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 8), sharey=True)

sns.barplot(x=salary_by_company.values, y=salary_by_company.index, palette="viridis", ax=ax1)
ax1.set_title("Top 10 puestos de trabajo 2023")
ax1.set_xlabel("Salario medio (USD)")
ax1.set_ylabel("Compañía")

for i, company in enumerate(salary_by_company.index):
    ax2.text(0, i, job_by_company[company], va='center')
ax2.set_title("Puesto de trabajo más común")
ax2.set_xlim(0, 1)
ax2.axis('off')
plt.tight_layout()
# plt.show()
plt.savefig('Top_10_trabajos_company.png', dpi=300, bbox_inches='tight')
plt.close()
# Out:
# <ipython-input-3-81e80e0b7983>:117: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=salary_by_company.values, y=salary_by_company.index, palette="viridis", ax=ax1)

# %%
# JSON data de la Query 3
data_q3 = [
  {
    "job_id": 40145,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 550000.0,
    "job_title": "Staff Data Scientist/Quant Researcher",
    "company_name": "Selby Jennings",
    "habilidades": "sql"
  },
  {
    "job_id": 40145,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 550000.0,
    "job_title": "Staff Data Scientist/Quant Researcher",
    "company_name": "Selby Jennings",
    "habilidades": "python"
  },
  {
    "job_id": 1714768,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 525000.0,
    "job_title": "Staff Data Scientist - Business Analytics",
    "company_name": "Selby Jennings",
    "habilidades": "sql"
  },
  {
    "job_id": 1131472,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 375000.0,
    "job_title": "Data Scientist",
    "company_name": "Algo Capital Group",
    "habilidades": "sql"
  },
  {
    "job_id": 1131472,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 375000.0,
    "job_title": "Data Scientist",
    "company_name": "Algo Capital Group",
    "habilidades": "python"
  },
  {
    "job_id": 1131472,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 375000.0,
    "job_title": "Data Scientist",
    "company_name": "Algo Capital Group",
    "habilidades": "java"
  },
  {
    "job_id": 1131472,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 375000.0,
    "job_title": "Data Scientist",
    "company_name": "Algo Capital Group",
    "habilidades": "cassandra"
  },
  {
    "job_id": 1131472,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 375000.0,
    "job_title": "Data Scientist",
    "company_name": "Algo Capital Group",
    "habilidades": "spark"
  },
  {
    "job_id": 1131472,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 375000.0,
    "job_title": "Data Scientist",
    "company_name": "Algo Capital Group",
    "habilidades": "hadoop"
  },
  {
    "job_id": 1131472,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 375000.0,
    "job_title": "Data Scientist",
    "company_name": "Algo Capital Group",
    "habilidades": "tableau"
  },
  {
    "job_id": 126218,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 320000.0,
    "job_title": "Director Level - Product Management - Data Science",
    "company_name": "Teramind",
    "habilidades": "azure"
  },
  {
    "job_id": 126218,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 320000.0,
    "job_title": "Director Level - Product Management - Data Science",
    "company_name": "Teramind",
    "habilidades": "aws"
  },
  {
    "job_id": 126218,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 320000.0,
    "job_title": "Director Level - Product Management - Data Science",
    "company_name": "Teramind",
    "habilidades": "tensorflow"
  },
  {
    "job_id": 126218,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 320000.0,
    "job_title": "Director Level - Product Management - Data Science",
    "company_name": "Teramind",
    "habilidades": "keras"
  },
  {
    "job_id": 126218,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 320000.0,
    "job_title": "Director Level - Product Management - Data Science",
    "company_name": "Teramind",
    "habilidades": "pytorch"
  },
  {
    "job_id": 126218,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 320000.0,
    "job_title": "Director Level - Product Management - Data Science",
    "company_name": "Teramind",
    "habilidades": "scikit-learn"
  },
  {
    "job_id": 126218,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 320000.0,
    "job_title": "Director Level - Product Management - Data Science",
    "company_name": "Teramind",
    "habilidades": "datarobot"
  },
  {
    "job_id": 226011,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 300000.0,
    "job_title": "Distinguished Data Scientist",
    "company_name": "Walmart",
    "habilidades": "scala"
  },
  {
    "job_id": 226011,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 300000.0,
    "job_title": "Distinguished Data Scientist",
    "company_name": "Walmart",
    "habilidades": "java"
  },
  {
    "job_id": 226011,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 300000.0,
    "job_title": "Distinguished Data Scientist",
    "company_name": "Walmart",
    "habilidades": "spark"
  },
  {
    "job_id": 226011,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 300000.0,
    "job_title": "Distinguished Data Scientist",
    "company_name": "Walmart",
    "habilidades": "tensorflow"
  },
  {
    "job_id": 226011,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 300000.0,
    "job_title": "Distinguished Data Scientist",
    "company_name": "Walmart",
    "habilidades": "pytorch"
  },
  {
    "job_id": 226011,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 300000.0,
    "job_title": "Distinguished Data Scientist",
    "company_name": "Walmart",
    "habilidades": "kubernetes"
  },
  {
    "job_id": 129924,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 300000.0,
    "job_title": "Director of Data Science",
    "company_name": "Storm4",
    "habilidades": "python"
  },
  {
    "job_id": 129924,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 300000.0,
    "job_title": "Director of Data Science",
    "company_name": "Storm4",
    "habilidades": "pandas"
  },
  {
    "job_id": 129924,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 300000.0,
    "job_title": "Director of Data Science",
    "company_name": "Storm4",
    "habilidades": "numpy"
  },
  {
    "job_id": 457991,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 300000.0,
    "job_title": "Head of Battery Data Science",
    "company_name": "Lawrence Harvey",
    "habilidades": "python"
  },
  {
    "job_id": 457991,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 300000.0,
    "job_title": "Head of Battery Data Science",
    "company_name": "Lawrence Harvey",
    "habilidades": "aws"
  },
  {
    "job_id": 457991,
    "job_title_short": "Data Scientist",
    "salary_year_avg": 300000.0,
    "job_title": "Head of Battery Data Science",
    "company_name": "Lawrence Harvey",
    "habilidades": "gcp"
  }
]

df = pd.DataFrame(data_q3)

# %%
# 1.Salario medio por Compañía

salary_by_company = df.groupby('company_name')['salary_year_avg'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=salary_by_company.values, y=salary_by_company.index, palette="viridis")
plt.title("Salario medio por Compañía")
plt.xlabel("Salario medio (USD)")
plt.ylabel("Compañía")
plt.tight_layout()
plt.savefig('salario_por_compania.png', dpi=300, bbox_inches='tight')
plt.close()
# plt.show()

# 2.Frecuencia de las skills en cada posición
skills_frequency = df['habilidades'].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=skills_frequency.values, y=skills_frequency.index, palette="magma")
plt.title("Frecuencia de las skills en cada posición")
plt.xlabel("Frecuencia")
plt.ylabel("Skill")
plt.tight_layout()
plt.savefig('frecuencia_skills.png', dpi=300, bbox_inches='tight')
plt.close()
# plt.show()
# Out:
# <ipython-input-12-8bbec99c60cf>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=salary_by_company.values, y=salary_by_company.index, palette="viridis")
# <ipython-input-12-8bbec99c60cf>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=skills_frequency.values, y=skills_frequency.index, palette="magma")
